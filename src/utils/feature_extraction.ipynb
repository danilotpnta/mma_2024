# %%
import clip
import torch
import numpy
import pandas
import PIL.Image
from umap import UMAP
from tqdm import tqdm
from src import config
from sklearn.manifold import TSNE


def calculate_clip_embeddings(dataset):

    model, preprocess = clip.load("ViT-B/32", device="cpu")
    clip_embeddings = []
    for image_name in tqdm(dataset["image_path"]):
        image = PIL.Image.open(image_name)
        image_input = preprocess(image).unsqueeze(0).to("cpu")
        with torch.no_grad():
            clip_embeddings.append(model.encode_image(image_input).cpu().numpy())
    clip_embeddings = numpy.concatenate(clip_embeddings, axis=0)

    return clip_embeddings


def calculate_umap(clip_embeddings):

    umap_embeddings = UMAP(metric="cosine", n_components=2).fit_transform(
        clip_embeddings
    )
    umap_x, umap_y = umap_embeddings[:, 0], umap_embeddings[:, 1]

    return umap_x, umap_y


def calculate_tsne(clip_embeddings):

    tsne_embeddings = TSNE(metric="cosine", n_components=2).fit_transform(
        clip_embeddings
    )
    tsne_x, tsne_y = tsne_embeddings[:, 0], tsne_embeddings[:, 1]

    return tsne_x, tsne_y


def generate_projection_data():

    dataset = pandas.read_csv(config.DATASET_PATH)
    dataset_sample = (
        dataset.sample(n=config.DATASET_SAMPLE_SIZE, random_state=1)
        if config.DATASET_SAMPLE_SIZE
        else dataset
    )
    print("Calculating clip embeddings")
    clip_embeddings = calculate_clip_embeddings(dataset_sample)
    umap_x, umap_y = calculate_umap(clip_embeddings)
    print("Calculating umap")
    tsne_x, tsne_y = calculate_tsne(clip_embeddings)
    print("Calculating tsne")
    augmented_dataset = dataset_sample.assign(
        umap_x=umap_x, umap_y=umap_y, tsne_x=tsne_x, tsne_y=tsne_y
    )
    augmented_dataset.to_csv(config.AUGMENTED_DATASET_PATH, index=False)
    print("Saving augmented dataset to", config.AUGMENTED_DATASET_PATH)


if __name__ == "__main__":
    generate_projection_data()

# %%
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipd
import librosa
import librosa.display
import os
import json
from src import config
from scipy.special import softmax
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 8
#       6 import os
#       7 import json
# ----> 8 from src import config
#       9 from scipy.special import softmax
#
# ModuleNotFoundError: No module named 'src'

# %%
# class that uses the librosa library to analyze the key that an mp3 is in
# arguments:
#     waveform: an mp3 file loaded by librosa, ideally separated out from any percussive sources
#     sr: sampling rate of the mp3, which can be obtained when the file is read with librosa
#     tstart and tend: the range in seconds of the file to be analyzed; default to the beginning and end of file if not specified
class Tonal_Fragment(object):
    def __init__(self, waveform, sr, tstart=None, tend=None):
        self.waveform = waveform
        self.sr = sr
        self.tstart = tstart
        self.tend = tend
        
        if self.tstart is not None:
            self.tstart = librosa.time_to_samples(self.tstart, sr=self.sr)
        if self.tend is not None:
            self.tend = librosa.time_to_samples(self.tend, sr=self.sr)
        self.y_segment = self.waveform[self.tstart:self.tend]
        self.chromograph = librosa.feature.chroma_cqt(y=self.y_segment, sr=self.sr, bins_per_octave=24)
        
        # chroma_vals is the amount of each pitch class present in this time interval
        self.chroma_vals = []
        for i in range(12):
            self.chroma_vals.append(np.sum(self.chromograph[i]))
        pitches = ['C','C#','D','D#','E','F','F#','G','G#','A','A#','B']
        # dictionary relating pitch names to the associated intensity in the song
        self.keyfreqs = {pitches[i]: self.chroma_vals[i] for i in range(12)} 
        
        keys = [pitches[i] + ' major' for i in range(12)] + [pitches[i] + ' minor' for i in range(12)]

        # use of the Krumhansl-Schmuckler key-finding algorithm, which compares the chroma
        # data above to typical profiles of major and minor keys:
        maj_profile = [6.35, 2.23, 3.48, 2.33, 4.38, 4.09, 2.52, 5.19, 2.39, 3.66, 2.29, 2.88]
        min_profile = [6.33, 2.68, 3.52, 5.38, 2.60, 3.53, 2.54, 4.75, 3.98, 2.69, 3.34, 3.17]

        # finds correlations between the amount of each pitch class in the time interval and the above profiles,
        # starting on each of the 12 pitches. then creates dict of the musical keys (major/minor) to the correlation
        self.min_key_corrs = []
        self.maj_key_corrs = []
        for i in range(12):
            key_test = [self.keyfreqs.get(pitches[(i + m)%12]) for m in range(12)]
            # correlation coefficients (strengths of correlation for each key)
            self.maj_key_corrs.append(round(np.corrcoef(maj_profile, key_test)[1,0], 3))
            self.min_key_corrs.append(round(np.corrcoef(min_profile, key_test)[1,0], 3))

        # names of all major and minor keys
        self.key_dict = {**{keys[i]: self.maj_key_corrs[i] for i in range(12)}, 
                         **{keys[i+12]: self.min_key_corrs[i] for i in range(12)}}
        
        # this attribute represents the key determined by the algorithm
        self.key = max(self.key_dict, key=self.key_dict.get)
        self.bestcorr = max(self.key_dict.values())
        
        # this attribute represents the second-best key determined by the algorithm,
        # if the correlation is close to that of the actual key determined
        self.altkey = None
        self.altbestcorr = None

        for key, corr in self.key_dict.items():
            if corr > self.bestcorr*0.9 and corr != self.bestcorr:
                self.altkey = key
                self.altbestcorr = corr
                
    # prints the relative prominence of each pitch class            
    def print_chroma(self):
        self.chroma_max = max(self.chroma_vals)
        for key, chrom in self.keyfreqs.items():
            print(key, '\t', f'{chrom/self.chroma_max:5.3f}')
                
    # prints the correlation coefficients associated with each major/minor key
    def corr_table(self):
        for key, corr in self.key_dict.items():
            print(key, '\t', f'{corr:6.3f}')
    
    # printout of the key determined by the algorithm; if another key is close, that key is mentioned
    def print_key(self):
        print("likely key: ", max(self.key_dict, key=self.key_dict.get), ", correlation: ", self.bestcorr, sep='')
        if self.altkey is not None:
                print("also possible: ", self.altkey, ", correlation: ", self.altbestcorr, sep='')
    
    # prints a chromagram of the file, showing the intensity of each pitch class over time
    def chromagram(self, title=None):
        C = librosa.feature.chroma_cqt(y=self.waveform, sr=sr, bins_per_octave=24)
        plt.figure(figsize=(12,4))
        librosa.display.specshow(C, sr=sr, x_axis='time', y_axis='chroma', vmin=0, vmax=1)
        if title is None:
            plt.title('Chromagram')
        else:
            plt.title(title)
        plt.colorbar()
        plt.tight_layout()

        plt.show()

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
import librosa
import librosa.display
import os
import config
# class that uses the librosa library to analyze the key that an mp3 is in
# arguments:
#     waveform: an mp3 file loaded by librosa, ideally separated out from any percussive sources
#     sr: sampling rate of the mp3, which can be obtained when the file is read with librosa
#     tstart and tend: the range in seconds of the file to be analyzed; default to the beginning and end of file if not specified
class Tonal_Fragment(object):
    def __init__(self, waveform, sr, tstart=None, tend=None):
        self.waveform = waveform
        self.sr = sr
        self.tstart = tstart
        self.tend = tend
        
        if self.tstart is not None:
            self.tstart = librosa.time_to_samples(self.tstart, sr=self.sr)
        if self.tend is not None:
            self.tend = librosa.time_to_samples(self.tend, sr=self.sr)
        self.y_segment = self.waveform[self.tstart:self.tend]
        self.chromograph = librosa.feature.chroma_cqt(y=self.y_segment, sr=self.sr, bins_per_octave=24)
        
        # chroma_vals is the amount of each pitch class present in this time interval
        self.chroma_vals = []
        for i in range(12):
            self.chroma_vals.append(np.sum(self.chromograph[i]))
        pitches = ['C','C#','D','D#','E','F','F#','G','G#','A','A#','B']
        # dictionary relating pitch names to the associated intensity in the song
        self.keyfreqs = {pitches[i]: self.chroma_vals[i] for i in range(12)} 
        
        keys = [pitches[i] + ' major' for i in range(12)] + [pitches[i] + ' minor' for i in range(12)]

        # use of the Krumhansl-Schmuckler key-finding algorithm, which compares the chroma
        # data above to typical profiles of major and minor keys:
        maj_profile = [6.35, 2.23, 3.48, 2.33, 4.38, 4.09, 2.52, 5.19, 2.39, 3.66, 2.29, 2.88]
        min_profile = [6.33, 2.68, 3.52, 5.38, 2.60, 3.53, 2.54, 4.75, 3.98, 2.69, 3.34, 3.17]

        # finds correlations between the amount of each pitch class in the time interval and the above profiles,
        # starting on each of the 12 pitches. then creates dict of the musical keys (major/minor) to the correlation
        self.min_key_corrs = []
        self.maj_key_corrs = []
        for i in range(12):
            key_test = [self.keyfreqs.get(pitches[(i + m)%12]) for m in range(12)]
            # correlation coefficients (strengths of correlation for each key)
            self.maj_key_corrs.append(round(np.corrcoef(maj_profile, key_test)[1,0], 3))
            self.min_key_corrs.append(round(np.corrcoef(min_profile, key_test)[1,0], 3))

        # names of all major and minor keys
        self.key_dict = {**{keys[i]: self.maj_key_corrs[i] for i in range(12)}, 
                         **{keys[i+12]: self.min_key_corrs[i] for i in range(12)}}
        
        # this attribute represents the key determined by the algorithm
        self.key = max(self.key_dict, key=self.key_dict.get)
        self.bestcorr = max(self.key_dict.values())
        
        # this attribute represents the second-best key determined by the algorithm,
        # if the correlation is close to that of the actual key determined
        self.altkey = None
        self.altbestcorr = None

        for key, corr in self.key_dict.items():
            if corr > self.bestcorr*0.9 and corr != self.bestcorr:
                self.altkey = key
                self.altbestcorr = corr
                
    # prints the relative prominence of each pitch class            
    def print_chroma(self):
        self.chroma_max = max(self.chroma_vals)
        for key, chrom in self.keyfreqs.items():
            print(key, '\t', f'{chrom/self.chroma_max:5.3f}')
                
    # prints the correlation coefficients associated with each major/minor key
    def corr_table(self):
        for key, corr in self.key_dict.items():
            print(key, '\t', f'{corr:6.3f}')
    
    # printout of the key determined by the algorithm; if another key is close, that key is mentioned
    def print_key(self):
        print("likely key: ", max(self.key_dict, key=self.key_dict.get), ", correlation: ", self.bestcorr, sep='')
        if self.altkey is not None:
                print("also possible: ", self.altkey, ", correlation: ", self.altbestcorr, sep='')
    
    # prints a chromagram of the file, showing the intensity of each pitch class over time
    def chromagram(self, title=None):
        C = librosa.feature.chroma_cqt(y=self.waveform, sr=sr, bins_per_octave=24)
        plt.figure(figsize=(12,4))
        librosa.display.specshow(C, sr=sr, x_axis='time', y_axis='chroma', vmin=0, vmax=1)
        if title is None:
            plt.title('Chromagram')
        else:
            plt.title(title)
        plt.colorbar()
        plt.tight_layout()
        plt.show()

top_3_keys = {}
print(config.GTZAN_DIR)

for root, dirs, files in os.walk(config.GTZAN_GENRES_DIR):
    print("entering here")
    for file in files:
        if file.endswith('.wav'):
            audio_path = os.path.join(root, file)
            try:
                y, sr = librosa.load(audio_path)
                y_harmonic, y_percussive = librosa.effects.hpss(y)
                tf = Tonal_Fragment(y_harmonic, sr)  # Assuming Tonal_Fragment and its properties are defined correctly elsewhere
                
                # Calculate total frequency for probability calculation
                # Original correlation values
                correlation_values = np.array(list(tf.key_dict.values()))

                # # Normalize correlation values to be positive
                abs_correlations = np.abs(correlation_values)
                #exp_correlations = np.exp(correlation_values)

                #probabilities = softmax(correlation_values)
                
                # Convert adjusted values to probabilities
                probabilities = abs_correlations / np.sum(abs_correlations)
                #probabilities = exp_correlations / np.sum(exp_correlations)

                # convert to percentage
                probabilities = probabilities * 100

                # Print the probabilities
                #print(probabilities)
                prob = sorted(probabilities, reverse=True)
                
                # Get top keys sorted by their frequencies
                top_keys = sorted(tf.key_dict, key=tf.key_dict.get, reverse=True)[:3]
                
                # Create a nested dictionary for each file
                file_dict = {}
                for i in range(3):
                    # key_with_freq = f"{key}_{tf.key_dict[key]}"
                    # print(key_with_freq)
                    # probability = tf.key_dict[key] / total_freq
                    # file_dict[key_with_freq] = probability
                    # print(key)
                    #print(tf.key_dict[top_keys[i]])
                    # probability = tf.key_dict[key] / total_freq
                    print(top_keys[i], round(prob[i],2))
                    file_dict[top_keys[i]] = round(prob[i],2)
                
                top_3_keys[file] = file_dict
                
            except Exception as e:
                print(f"Error processing {audio_path}: {e}")
                continue

print(top_3_keys)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /Users/datoapanta/Desktop/mma_2024/src/dataset/data/gtzan
# {}

# %%
os.walk(config.GTZAN_GENRES_DIR)
# Out:
# <generator object walk at 0x7fbc78638f90>

# %%
for root, dirs, files in os.walk(config.GTZAN_GENRES_DIR):
    print("entering here")

# %%
import os

if os.path.isdir(config.GTZAN_GENRES_DIR):
    print(f"{config.GTZAN_GENRES_DIR} exists and is a directory.")
else:
    print(f"{config.GTZAN_GENRES_DIR} does not exist or is not a directory.")
# Out:
# /Users/datoapanta/Desktop/mma_2024/src/dataset/data/gtzan/genres does not exist or is not a directory.

# %%
print(config.DATA_DIR)
print(config.DATASET_DIR)
# Out:
# /Users/datoapanta/Desktop/mma_2024/src/dataset/data
# /Users/datoapanta/Desktop/mma_2024/src/dataset

# %%
from pathlib import Path
print(Path(__file__).parent.parent.parent)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 from pathlib import Path
# ----> 2 print(Path(__file__).parent.parent.parent)
#
# NameError: name '__file__' is not defined

# %%
import numpy as np
import librosa
import os

class Tonal_Fragment:
    def __init__(self, waveform, sr, tstart=None, tend=None):
        self.waveform = waveform
        self.sr = sr
        self.tstart = librosa.time_to_samples(tstart, sr=sr) if tstart is not None else None
        self.tend = librosa.time_to_samples(tend, sr=sr) if tend is not None else None
        self.y_segment = self.waveform[self.tstart:self.tend]
        self.chromograph = librosa.feature.chroma_cqt(y=self.y_segment, sr=self.sr, bins_per_octave=24)
        
        self.chroma_vals = [np.sum(self.chromograph[i]) for i in range(12)]
        pitches = ['C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#', 'A', 'A#', 'B']
        self.keyfreqs = {pitches[i]: self.chroma_vals[i] for i in range(12)}
        
        keys = [pitches[i] + ' major' for i in range(12)] + [pitches[i] + ' minor' for i in range(12)]
        
        maj_profile = [6.35, 2.23, 3.48, 2.33, 4.38, 4.09, 2.52, 5.19, 2.39, 3.66, 2.29, 2.88]
        min_profile = [6.33, 2.68, 3.52, 5.38, 2.60, 3.53, 2.54, 4.75, 3.98, 2.69, 3.34, 3.17]
        
        self.maj_key_corrs = [round(np.corrcoef(maj_profile, [self.keyfreqs[pitches[(i + m) % 12]] for m in range(12)])[1, 0], 3) for i in range(12)]
        self.min_key_corrs = [round(np.corrcoef(min_profile, [self.keyfreqs[pitches[(i + m) % 12]] for m in range(12)])[1, 0], 3) for i in range(12)]
        
        self.key_dict = {**{keys[i]: self.maj_key_corrs[i] for i in range(12)},
                         **{keys[i + 12]: self.min_key_corrs[i] for i in range(12)}}
        
        self.key = max(self.key_dict, key=self.key_dict.get)
        self.bestcorr = max(self.key_dict.values())
        
        self.altkey = None
        self.altbestcorr = None
        for key, corr in self.key_dict.items():
            if corr > self.bestcorr * 0.9 and corr != self.bestcorr:
                self.altkey = key
                self.altbestcorr = corr

def extract_keys(data):
    top_3_keys = {}

    for index, row in data.iterrows():
        audio_path = row['file_path']
        try:
            y, sr = librosa.load(audio_path)
            y_harmonic, _ = librosa.effects.hpss(y)
            tf = Tonal_Fragment(y_harmonic, sr)
            
            correlation_values = np.array(list(tf.key_dict.values()))
            abs_correlations = np.abs(correlation_values)
            probabilities = abs_correlations / np.sum(abs_correlations)
            probabilities = probabilities * 100
            prob = sorted(probabilities, reverse=True)
            
            top_keys = sorted(tf.key_dict, key=tf.key_dict.get, reverse=True)[:3]
            file_dict = {top_keys[i]: round(prob[i], 2) for i in range(3)}
            
            top_3_keys[row['filename']] = file_dict
            
        except Exception as e:
            print(f"Error processing {audio_path}: {e}")
            continue
    
    data['keys'] = data['filename'].map(lambda x: top_3_keys.get(x, {}))
    return data

# %%
import pandas as pd
columns_to_keep = ['filename', 'label', 'tempo']
data = pd.read_csv("/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/features_30_sec.csv", usecols=columns_to_keep) 

file_paths = {}
# save in a new column the filepath from each song
for root, dirs, files in os.walk("/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/genres"):
    for file in files:
        if file.endswith('.wav'):
            audio_path = os.path.join(root, file)
            file_paths[file] = audio_path

data['file_path'] = data['filename'].map(file_paths)

# reorder columns
data = data[['filename', 'label', 'file_path', 'tempo']]
data = extract_keys(data)
# Out:
# /var/folders/bz/yv6zpqcs0vgf1wt80wfp36t40000gn/T/ipykernel_3065/2216179541.py:45: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(audio_path)
# /Users/datoapanta/opt/anaconda3/envs/mma_2024/lib/python3.8/site-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Error processing /Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/genres/jazz/jazz.00054.wav:

# %%
data.to_csv("/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/metadata.csv", index=False)

# %%
import numpy as np
# Function to calculate loudness
def calculate_loudness(file_path):
    try:
        y, sr = librosa.load(file_path)
        S = librosa.feature.melspectrogram(y=y, sr=sr)
        S_dB = librosa.power_to_db(S, ref=np.max)
        loudness = S_dB.mean()
        rounded_loudness = round(float(loudness), 2)
        # print(f"Loudness of {file_path} is {rounded_loudness} dB")
        return rounded_loudness
    except Exception as e:
        return None

# Calculate loudness for each file and add it to the DataFrame
data['loudness'] = data['file_path'].apply(calculate_loudness)
# Out:
# /var/folders/bz/yv6zpqcs0vgf1wt80wfp36t40000gn/T/ipykernel_3065/3053536440.py:5: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(file_path)
# /Users/datoapanta/opt/anaconda3/envs/mma_2024/lib/python3.8/site-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)

# %%
data.to_csv("/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/metadata_.csv", index=False)

# %%
# Out:
# Song recognition failed for pop.00072.wav.
# Song recognition failed for pop.00048.wav.
# Song recognition failed for pop.00006.wav.
# Song recognition failed for pop.00014.wav.
# Song recognition failed for pop.00017.wav.
# Song recognition failed for metal.00009.wav.
# Song recognition failed for metal.00020.wav.
# Song recognition failed for metal.00085.wav.
# Song recognition failed for metal.00074.wav.
# Song recognition failed for metal.00011.wav.
# Song recognition failed for metal.00039.wav.
# Song recognition failed for disco.00085.wav.
# Song recognition failed for disco.00084.wav.
# Song recognition failed for disco.00069.wav.
# Song recognition failed for disco.00080.wav.
# Song recognition failed for disco.00081.wav.
# Song recognition failed for disco.00030.wav.
# Song recognition failed for disco.00010.wav.
# Song recognition failed for disco.00004.wav.
# Song recognition failed for disco.00012.wav.
# Song recognition failed for disco.00006.wav.
# Song recognition failed for disco.00071.wav.
# Song recognition failed for blues.00096.wav.
# Song recognition failed for blues.00097.wav.
# Song recognition failed for reggae.00094.wav.
# Song recognition failed for reggae.00086.wav.
# Song recognition failed for reggae.00051.wav.
# Song recognition failed for reggae.00045.wav.
# Song recognition failed for reggae.00065.wav.
# Song recognition failed for classical.00093.wav.
# Song recognition failed for classical.00046.wav.
# Song recognition failed for classical.00080.wav.
# Song recognition failed for hiphop.00035.wav.
# Song recognition failed for hiphop.00030.wav.
# Song recognition failed for hiphop.00031.wav.
# Song recognition failed for hiphop.00033.wav.
# Song recognition failed for hiphop.00032.wav.
# Song recognition failed for hiphop.00026.wav.
# Song recognition failed for hiphop.00000.wav.
# Song recognition failed for country.00000.wav.
# Song recognition failed for country.00001.wav.
# Song recognition failed for country.00003.wav.
# Song recognition failed for country.00002.wav.
# Song recognition failed for country.00006.wav.
# Song recognition failed for country.00007.wav.
# Song recognition failed for country.00005.wav.
# Song recognition failed for country.00038.wav.
# Song recognition failed for country.00004.wav.
# Song recognition failed for country.00009.wav.
# Song recognition failed for country.00034.wav.
# Song recognition failed for country.00008.wav.
# Song recognition failed for country.00036.wav.
# Song recognition failed for country.00037.wav.
# Song recognition failed for country.00033.wav.
# Song recognition failed for country.00027.wav.
# Song recognition failed for country.00032.wav.
# Song recognition failed for country.00030.wav.
# Song recognition failed for country.00031.wav.
# Song recognition failed for country.00042.wav.
# Song recognition failed for country.00044.wav.
# Song recognition failed for jazz.00066.wav.
# Song recognition failed for jazz.00054.wav.
# Song recognition failed for jazz.00050.wav.
# No new files to process.
# Processing completed. Metadata updated.

# %%
import os
import requests
import json
import pandas as pd
from PIL import Image
from io import BytesIO
import base64
import time

# Last.fm credentials
lastfm_api_key = '6f9bf6923b90e8c77408f7d6e20f5292'

# Spotify credentials (You need to set up a Spotify Developer account and get the API credentials)
spotify_client_id = '667b4c424f0041489f7327d660e49dc9'
spotify_client_secret = '41760d74bc3d48cebb520e904ed9df3c'

KNOWN_PLACEHOLDER_URLS = [
    'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png'
]

def get_spotify_token():
    url = 'https://accounts.spotify.com/api/token'
    headers = {
        'Authorization': 'Basic ' + base64.b64encode(f'{spotify_client_id}:{spotify_client_secret}'.encode()).decode('utf-8')
    }
    data = {
        'grant_type': 'client_credentials'
    }
    response = requests.post(url, headers=headers, data=data)
    token_info = response.json()
    return token_info['access_token']

def is_placeholder_image(image):
    """Check if the image is a placeholder (generic) image."""
    placeholder_color = (229, 229, 229)  # The specific color of the star image
    white_color = (255, 255, 255)
    
    # Check several key points for the placeholder image pattern
    points_to_check = [
        (0, 0),
        (100, 100),
        (199, 199),
        (0, 199),
        (199, 0),
        (50, 50),
        (150, 150)
    ]
    
    for point in points_to_check:
        if image.getpixel(point) != placeholder_color and image.getpixel(point) != white_color:
            return False
    return True

def is_placeholder_url(url):
    """Check if the URL is a known placeholder image URL."""
    return url in KNOWN_PLACEHOLDER_URLS

def fetch_cover_image_lastfm(title, artist):
    url = f"http://ws.audioscrobbler.com/2.0/?method=track.getInfo&api_key={lastfm_api_key}&artist={artist}&track={title}&format=json"
    response = requests.get(url)
    try:
        data = response.json()
        if 'track' in data and 'album' in data['track'] and 'image' in data['track']['album']:
            cover_url = data['track']['album']['image'][-1]['#text']
            print(f"Fetched URL from Last.fm: {cover_url}")
            if not is_placeholder_url(cover_url) and is_valid_image_url(cover_url):
                return cover_url.replace('64x64', '200x200')
            else:
                return fetch_album_image_lastfm(artist)
        else:
            return fetch_album_image_lastfm(artist)
    except (json.JSONDecodeError, KeyError) as e:
        print(f"Error fetching cover image from Last.fm for '{title}' by '{artist}': {e}")
        return fetch_album_image_lastfm(artist)

def fetch_album_image_lastfm(artist):
    url = f"http://ws.audioscrobbler.com/2.0/?method=artist.getInfo&api_key={lastfm_api_key}&artist={artist}&format=json"
    response = requests.get(url)
    try:
        data = response.json()
        if 'artist' in data and 'image' in data['artist']:
            cover_url = data['artist']['image'][-1]['#text']
            print(f"Fetched album URL from Last.fm: {cover_url}")
            if not is_placeholder_url(cover_url) and is_valid_image_url(cover_url):
                return cover_url.replace('64x64', '200x200')
        return None
    except (json.JSONDecodeError, KeyError) as e:
        print(f"Error fetching artist image from Last.fm for '{artist}': {e}")
        return None

def fetch_cover_image_spotify(title, artist, token):
    url = f"https://api.spotify.com/v1/search?q=track:{title}%20artist:{artist}&type=track&limit=1"
    headers = {
        'Authorization': f'Bearer {token}'
    }
    response = requests.get(url, headers=headers)
    try:
        data = response.json()
        if data['tracks']['items']:
            cover_url = data['tracks']['items'][0]['album']['images'][0]['url']
            print(f"Fetched URL from Spotify: {cover_url}")
            if is_valid_image_url(cover_url):
                return cover_url
            else:
                return fetch_album_image_spotify(artist, token)
        else:
            return fetch_album_image_spotify(artist, token)
    except (json.JSONDecodeError, KeyError) as e:
        print(f"Error fetching cover image from Spotify for '{title}' by '{artist}': {e}")
        return fetch_album_image_spotify(artist, token)

def fetch_album_image_spotify(artist, token):
    url = f"https://api.spotify.com/v1/search?q=artist:{artist}&type=artist&limit=1"
    headers = {
        'Authorization': f'Bearer {token}'
    }
    response = requests.get(url, headers=headers)
    try:
        data = response.json()
        if data['artists']['items'] and 'images' in data['artists']['items'][0]:
            cover_url = data['artists']['items'][0]['images'][0]['url']
            print(f"Fetched album URL from Spotify: {cover_url}")
            if is_valid_image_url(cover_url):
                return cover_url
        return None
    except (json.JSONDecodeError, KeyError, IndexError) as e:
        print(f"Error fetching artist image from Spotify for '{artist}': {e}")
        return None

def is_valid_image_url(url):
    """Check if the image URL is valid and not a placeholder."""
    if not url:
        print("Empty URL provided.")
        return False
    response = requests.get(url)
    image = Image.open(BytesIO(response.content))
    if image.mode == 'RGBA':
        image = image.convert('RGB')
    if is_placeholder_image(image):
        print("Placeholder image detected.")
        return False
    return True

def download_and_resize_cover_image(url, save_path):
    if not url:
        print(f"Invalid URL: {url}")
        return
    response = requests.get(url)
    image = Image.open(BytesIO(response.content))
    if image.mode == 'RGBA':
        image = image.convert('RGB')
    if is_placeholder_image(image):
        print(f"Placeholder image detected and skipped: {url}")
        return
    image = image.resize((200, 200))
    image.save(save_path)

def process_error_files(error_files, base_directory):
    token = get_spotify_token()
    for error_file in error_files:
        genre = os.path.basename(error_file).replace('_errors.csv', '')
        error_df = pd.read_csv(error_file)
        remaining_errors = []
        
        for _, row in error_df.iterrows():
            filename, title, artist = row['filename'], row['title'], row['artist']
            cover_url = fetch_cover_image_lastfm(title, artist)
            if not cover_url:
                cover_url = fetch_cover_image_spotify(title, artist, token)
                if not cover_url:
                    print(f"Cover image not found for '{title}' by '{artist}' from both Last.fm and Spotify. Retrying after delay.")
                    time.sleep(1)  # Delay before retrying
                    cover_url = fetch_cover_image_spotify(title, artist, token)

            if cover_url:
                try:
                    genre_dir = os.path.join(base_directory, 'images', genre)
                    os.makedirs(genre_dir, exist_ok=True)
                    save_path = os.path.join(genre_dir, f"{os.path.splitext(filename)[0]}_cover.jpg")
                    download_and_resize_cover_image(cover_url, save_path)
                    print(f"Cover image downloaded and resized for '{title}' by '{artist}' as '{save_path}'")
                except Exception as e:
                    print(f"Error downloading or resizing cover image for '{title}' by '{artist}': {e}")
                    remaining_errors.append((filename, title, artist))
            else:
                print(f"Cover image not found for '{title}' by '{artist}' from both Last.fm and Spotify.")
                remaining_errors.append((filename, title, artist))
        
        # Save remaining errors back to the CSV file
        if remaining_errors:
            remaining_error_df = pd.DataFrame(remaining_errors, columns=['filename', 'title', 'artist'])
            remaining_error_df.to_csv(error_file, index=False)
        else:
            os.remove(error_file)  # Remove the error file if all errors are resolved

if __name__ == "__main__":
    base_directory = '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan'
    error_files = [
        os.path.join(base_directory, 'errors', 'jazz_errors.csv'),
        os.path.join(base_directory, 'errors', 'country_errors.csv'),
        os.path.join(base_directory, 'errors', 'hiphop_errors.csv'),
        os.path.join(base_directory, 'errors', 'rock_errors.csv'),
        os.path.join(base_directory, 'errors', 'classical_errors.csv'),
        os.path.join(base_directory, 'errors', 'reggae_errors.csv'),
        os.path.join(base_directory, 'errors', 'disco_errors.csv'),
        os.path.join(base_directory, 'errors', 'metal_errors.csv'),
        os.path.join(base_directory, 'errors', 'pop_errors.csv')
    ]
    process_error_files(error_files, base_directory)
    print("Processing of error files completed.")
# Out:
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/ab67616d0000b273c1fab9d112967a4d8957985e
# Cover image downloaded and resized for 'Citizen Tain (Album Version)' by 'Branford Marsalis Trio' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/jazz/jazz.00029_cover.jpg'
# Fetched URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/7a533daa11f24339c350f901de3c9d76.png
# Cover image downloaded and resized for 'Sweet Lorraine (1991 Remastered)' by 'Henry "Red" Allen' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/jazz/jazz.00070_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/ab6761610000e5eb60531b02c778461b3048845b
# Cover image downloaded and resized for 'For Adults Only (feat. Don Braden & Bruce Cox)' by 'Joris Teepe' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/jazz/jazz.00056_cover.jpg'
# Fetched URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/a81b21b2ae12c4e5e8f7ccb9569988c8.png
# Cover image downloaded and resized for 'Brazilian Affair' by 'Bob Mintzer' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/jazz/jazz.00093_cover.jpg'
# Fetched URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/7a533daa11f24339c350f901de3c9d76.png
# Cover image downloaded and resized for 'Sweet Lorraine (1991 Remastered)' by 'Henry "Red" Allen' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/jazz/jazz.00044_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/ab67616d0000b273c1fab9d112967a4d8957985e
# Cover image downloaded and resized for 'Roused About (Album Version)' by 'Branford Marsalis Trio' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/jazz/jazz.00025_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/ab67616d0000b273c1fab9d112967a4d8957985e
# Cover image downloaded and resized for 'Dewey Baby (Album Version)' by 'Branford Marsalis Trio' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/jazz/jazz.00031_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/ab67616d0000b273c1fab9d112967a4d8957985e
# Cover image downloaded and resized for 'Gilligan's Isle (Album Version)' by 'Branford Marsalis Trio' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/jazz/jazz.00030_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/ab67616d0000b273c1fab9d112967a4d8957985e
# Cover image downloaded and resized for 'Beat's Remark (Album Version)' by 'Branford Marsalis Trio' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/jazz/jazz.00032_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/ab67616d0000b273c1fab9d112967a4d8957985e
# Cover image downloaded and resized for 'The Beautyful Ones Are Not Yet Born (Album Version)' by 'Branford Marsalis Trio' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/jazz/jazz.00026_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/ab67616d0000b273c1fab9d112967a4d8957985e
# Cover image downloaded and resized for 'Xavier's Lair (Album Version)' by 'Branford Marsalis Trio' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/jazz/jazz.00027_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/ab6761610000e5eb5f79cb1d93cfa9684c1f6dc9
# Cover image downloaded and resized for 'Out Of Control (Album Version)' by 'George Jones' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/country/country.00049_cover.jpg'
# Fetched URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/706812ef7acd47728e29475a5e60a368.png
# Cover image downloaded and resized for 'Blue Eyes Crying in the Rain (Album Version)' by 'Willie Nelson' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/country/country.00065_cover.jpg'
# Fetched URL from Last.fm:
# Empty URL provided.
# Fetched album URL from Last.fm:
# Empty URL provided.
# Cover image not found for 'Love Hurts' by 'Emmylou Harris and Carl Jackson' from both Last.fm and Spotify. Retrying after delay.
# Cover image not found for 'Love Hurts' by 'Emmylou Harris and Carl Jackson' from both Last.fm and Spotify.
# Fetched URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/74c1e17572da4054a5f4c8040f81e05a.png
# Cover image downloaded and resized for 'When I Call Your Name' by 'Vince Gill' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/country/country.00052_cover.jpg'
# Fetched URL from Last.fm:
# Empty URL provided.
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Error fetching artist image from Spotify for 'Lil Bow Wow': list index out of range
# Cover image not found for 'Bounce With Me (Edited Album Version)' by 'Lil Bow Wow' from both Last.fm and Spotify. Retrying after delay.
# Error fetching artist image from Spotify for 'Lil Bow Wow': list index out of range
# Cover image not found for 'Bounce With Me (Edited Album Version)' by 'Lil Bow Wow' from both Last.fm and Spotify.
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/705bcd56dc5dbf9ebc578a3ba8094e6d622862c2
# Cover image downloaded and resized for 'The Negotiation Limerick File (1999 - Remaster)' by 'Beastie Boys' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/hiphop/hiphop.00021_cover.jpg'
# Fetched URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/bc8b0d37758ed96e77e256b6db27b5ad.png
# Cover image downloaded and resized for 'Dog Sh*t' by 'Wu-Tang Clan' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/hiphop/hiphop.00041_cover.jpg'
# Fetched URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/a3c29d3ad50b4d0da35eb6c95c5f1ef2.png
# Cover image downloaded and resized for 'Leave This Off Your Fu*Kin Charts' by 'Public Enemy' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/hiphop/hiphop.00095_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/ab6761610000e5eba00b11c129b27a88fc72f36b
# Cover image downloaded and resized for 'Freestyle Gone Crazy' by 'Eminem' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/hiphop/hiphop.00080_cover.jpg'
# Fetched URL from Last.fm:
# Empty URL provided.
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/ab6761610000e5ebad53e714cc3481bd069bfc93
# Cover image downloaded and resized for 'Anything Can Happen (Album Version)' by 'Wyclef Jean' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/hiphop/hiphop.00043_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/ab6761610000e5eba00b11c129b27a88fc72f36b
# Cover image downloaded and resized for 'Thug Love (Our House)' by 'Eminem' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/hiphop/hiphop.00078_cover.jpg'
# Fetched album URL from Last.fm:
# Empty URL provided.
# Cover image not found for 'What Go Around Come Around, Kid (Album Version)' by '墓園三人組' from both Last.fm and Spotify. Retrying after delay.
# Cover image not found for 'What Go Around Come Around, Kid (Album Version)' by '墓園三人組' from both Last.fm and Spotify.
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/ab6761610000e5eba00b11c129b27a88fc72f36b
# Cover image downloaded and resized for 'Thug Love (Our House)' by 'Eminem' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/hiphop/hiphop.00076_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/705bcd56dc5dbf9ebc578a3ba8094e6d622862c2
# Cover image downloaded and resized for 'Sure Shot (Edited / 2005 Remaster)' by 'Beastie Boys' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/hiphop/hiphop.00012_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/207803ce008388d3427a685254f9de6a8f61dc2e
# Cover image downloaded and resized for 'Boogie with Stu (1993 Remaster)' by 'Led Zeppelin' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/rock/rock.00048_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched URL from Spotify: https://i.scdn.co/image/ab67616d0000b2732ed20979ab034dae4c04f060
# Cover image downloaded and resized for 'She's Got It Bad (2008 Remaster)' by 'Simply Red' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/rock/rock.00075_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched URL from Spotify: https://i.scdn.co/image/ab67616d0000b2732ed20979ab034dae4c04f060
# Cover image downloaded and resized for 'Freedom (2008 Remaster)' by 'Simply Red' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/rock/rock.00077_cover.jpg'
# Cover image not found for 'Against The Wind' by 'Bob Seeker & The Silver' from both Last.fm and Spotify. Retrying after delay.
# Cover image not found for 'Against The Wind' by 'Bob Seeker & The Silver' from both Last.fm and Spotify.
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/207803ce008388d3427a685254f9de6a8f61dc2e
# Cover image downloaded and resized for 'The Wanton Song (2012 Remaster)' by 'Led Zeppelin' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/rock/rock.00047_cover.jpg'
# Fetched URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/bdaaccd37305c37fb4a54fd0d80f53e9.png
# Cover image downloaded and resized for 'Wonderland (Remastered)' by 'Simply Red' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/rock/rock.00078_cover.jpg'
# Fetched URL from Last.fm:
# Empty URL provided.
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched URL from Spotify: https://i.scdn.co/image/ab67616d0000b27379d09b23611c00d9dabd2832
# Cover image downloaded and resized for 'Elephant Stone (Remastered Edit)' by 'The Stone Roses' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/rock/rock.00092_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched URL from Spotify: https://i.scdn.co/image/ab67616d0000b273cf2dc4b2b9cac16e3efda980
# Cover image downloaded and resized for 'African Skies (2002 Digital Remaster)' by 'Simple Minds' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/rock/rock.00055_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched URL from Spotify: https://i.scdn.co/image/ab67616d0000b273cf2dc4b2b9cac16e3efda980
# Cover image downloaded and resized for 'Let The Children Speak (2002 Digital Remaster)' by 'Simple Minds' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/rock/rock.00054_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/207803ce008388d3427a685254f9de6a8f61dc2e
# Cover image downloaded and resized for 'The Crunge (1993 Remaster)' by 'Led Zeppelin' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/rock/rock.00040_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched URL from Spotify: https://i.scdn.co/image/ab67616d0000b273cf2dc4b2b9cac16e3efda980
# Cover image downloaded and resized for 'Ghostrider (2002 Digital Remaster)' by 'Simple Minds' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/rock/rock.00056_cover.jpg'
# Fetched URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/1aec5cac8403fbda275b8200b77c8318.png
# Cover image downloaded and resized for 'Another One Bites The Dust' by 'Queen' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/rock/rock.00018_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/ab6761610000e5eb10d4a1b12c6ceda12d7cd248
# Cover image downloaded and resized for 'Good Vibrations(1999 Remastered Version)' by 'The Beach Boys' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/rock/rock.00027_cover.jpg'
# Fetched album URL from Last.fm:
# Empty URL provided.
# Cover image not found for 'Summer Mix (Live)' by 'DANIFORTY' from both Last.fm and Spotify. Retrying after delay.
# Cover image not found for 'Summer Mix (Live)' by 'DANIFORTY' from both Last.fm and Spotify.
# Fetched URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/79a696e1e82a4259bd55a6c6d0d50d9d.png
# Cover image downloaded and resized for 'Space Oddity (1997 Remaster)' by 'David Bowie' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/rock/rock.00034_cover.jpg'
# Fetched URL from Spotify: https://i.scdn.co/image/ab67616d0000b273d8d47cd789d60308baaf6f0c
# Cover image downloaded and resized for 'Fuge Für Klavier, AV 81/177 (Strauss)' by 'Wolfgang Sawallisch, Gitti Pirner & Johannes Ritzkowsky' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/classical/classical.00045_cover.jpg'
# Fetched album URL from Last.fm:
# Empty URL provided.
# Fetched album URL from Spotify: https://i.scdn.co/image/ab67616d0000b2738fbeac0d25ea381cd0ed18bc
# Cover image downloaded and resized for 'Shepherd's Hey' by 'Rundell, Clark' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/classical/classical.00086_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/932369b4022c95f0081ec285e6db56909e41c169
# Cover image downloaded and resized for 'Vivaldi Larghetto (from Piccolo Concerto in A minor, P. 83)' by 'Jean-Francois Paillard' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/classical/classical.00092_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/b43c570dd3475eb92f417edb7bc9026db11c2179
# Cover image downloaded and resized for 'Faeroe Island Dance (danse des îles Féroé)' by 'Percy Grainger' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/classical/classical.00084_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/6b82327ed38bf9786789810f6a96a555ff8693b5
# Cover image downloaded and resized for 'Spring: Largo e pianissimo sempre II.' by 'Leonard Slatkin' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/classical/classical.00090_cover.jpg'
# Fetched URL from Spotify: https://i.scdn.co/image/ab67616d0000b273d8d47cd789d60308baaf6f0c
# Cover image downloaded and resized for 'Konzert Für Waldhorn Mit Orchester - Oder Klavierbegleitung, Op. 11 (Trenner-Verz. 117): I. Allegro (Strauss)' by 'Wolfgang Sawallisch & Johannes Ritzkowsky' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/classical/classical.00043_cover.jpg'
# Fetched album URL from Last.fm:
# Empty URL provided.
# Fetched album URL from Spotify: https://i.scdn.co/image/ab67616d0000b273d3aa1119d16ab06a0b039526
# Cover image downloaded and resized for 'The Four Seasons, Op. 8: Concerto No. 2 for Violin in G Minor RV 315 "Summer": I. Allegro Non Molto' by 'José Louis Garcia' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/classical/classical.00094_cover.jpg'
# Fetched album URL from Last.fm:
# Empty URL provided.
# Fetched album URL from Spotify: https://i.scdn.co/image/ab67616d0000b273d3aa1119d16ab06a0b039526
# Cover image downloaded and resized for 'The Four Seasons, Op. 8: Concerto No. 2 for Violin in G Minor RV 315 "Summer": II. Adagio' by 'José Louis Garcia' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/classical/classical.00095_cover.jpg'
# Fetched album URL from Last.fm:
# Empty URL provided.
# Error fetching artist image from Spotify for 'Andrew Parrott/Taverner Consort/Taverner Choir/Taverner Players': list index out of range
# Cover image not found for 'Solemn Mass for the Feast of Sancta Maria della Salute in thanksgiving for the delivery of the City of Venice from the Plague, Bas' by 'Andrew Parrott/Taverner Consort/Taverner Choir/Taverner Players' from both Last.fm and Spotify. Retrying after delay.
# Error fetching artist image from Spotify for 'Andrew Parrott/Taverner Consort/Taverner Choir/Taverner Players': list index out of range
# Cover image not found for 'Solemn Mass for the Feast of Sancta Maria della Salute in thanksgiving for the delivery of the City of Venice from the Plague, Bas' by 'Andrew Parrott/Taverner Consort/Taverner Choir/Taverner Players' from both Last.fm and Spotify.
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/b43c570dd3475eb92f417edb7bc9026db11c2179
# Cover image downloaded and resized for 'Ye banks and Braes O' Bonnie Doon (O rives et coteaux de la gracieuse Doon)' by 'Percy Grainger' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/classical/classical.00083_cover.jpg'
# Fetched album URL from Spotify: https://i.scdn.co/image/ab67616d0000b2730cbd2108313813b846eee8ab
# Cover image downloaded and resized for 'Allegro from Violin Concerto in A minor, Op.3 No.6, RV356' by 'Jean-François Paillard,Orchestre de Chambre Jean-François Paillard' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/classical/classical.00097_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/ab6761610000e5ebd56134c89f7b5ccbd2a06ca1
# Cover image downloaded and resized for 'Concerto Nr. 2 in g-Moll, Op. 8 "Die vier Jahreszeiten": III. Presto, "Sommer"' by 'English Chamber Orchestra' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/classical/classical.00096_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/b43c570dd3475eb92f417edb7bc9026db11c2179
# Cover image downloaded and resized for 'Hill Song n° 2 (chant de montagne n° 2)' by 'Percy Grainger' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/classical/classical.00082_cover.jpg'
# Fetched album URL from Last.fm:
# Empty URL provided.
# Fetched album URL from Spotify: https://i.scdn.co/image/ab6761610000e5eb65e57a760099d14a0807cd9a
# Cover image downloaded and resized for 'Symphony No. 41 in C Major, K551 'Jupiter' - II. Andante cantabile' by 'Gunther Hasselmann' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/classical/classical.00027_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/ab6761610000e5ebc8b13e554131116bf311f242
# Cover image downloaded and resized for 'Mozart: Symphony No.39 in E flat, K.543 - 1. Adagio - Allegro' by 'Academy of St. Martin in the Fields' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/classical/classical.00018_cover.jpg'
# Fetched album URL from Last.fm:
# Empty URL provided.
# Fetched album URL from Spotify: https://i.scdn.co/image/ab6761610000e5eb65e57a760099d14a0807cd9a
# Cover image downloaded and resized for 'Symphony No. 39 in E Flat Major, K543 - III. Menuetto (Allegro)' by 'Gunther Hasselmann' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/classical/classical.00020_cover.jpg'
# Fetched album URL from Last.fm:
# Empty URL provided.
# Fetched album URL from Spotify: https://i.scdn.co/image/ab6761610000e5eb65e57a760099d14a0807cd9a
# Cover image downloaded and resized for 'Symphony No. 39 in E Flat Major, K543 - IV. Finale (Allegro)' by 'Gunther Hasselmann' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/classical/classical.00021_cover.jpg'
# Cover image not found for 'Quartet for Strings in F Major, M. 85: II. Assez vif - Très rythmé' by '茱麗亞弦樂四重奏團' from both Last.fm and Spotify. Retrying after delay.
# Cover image not found for 'Quartet for Strings in F Major, M. 85: II. Assez vif - Très rythmé' by '茱麗亞弦樂四重奏團' from both Last.fm and Spotify.
# Fetched URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/a2ded8100fcab10ab7b29547cc0c74d1.png
# Cover image downloaded and resized for 'J.S. Bach: Canonic Trio in F, BWV 1040' by 'Heinz Holliger' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/classical/classical.00004_cover.jpg'
# Fetched album URL from Last.fm:
# Empty URL provided.
# Fetched album URL from Spotify: https://i.scdn.co/image/ab6761610000e5eb65e57a760099d14a0807cd9a
# Cover image downloaded and resized for 'Symphony No. 36 in C Major, K425 'Linz' - I. Adagio - Allegro spiritoso' by 'Gunther Hasselmann' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/classical/classical.00011_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/ab6761610000e5ebc8b13e554131116bf311f242
# Cover image downloaded and resized for 'Mozart: Symphony No.38 in D, K.504  "Prague" - 1. Adagio - Allegro' by 'Academy of St. Martin in the Fields' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/classical/classical.00015_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/ab6761610000e5eb4a3d84f5e5908ba7a4a4554f
# Cover image downloaded and resized for 'Concerto for Oboe d'Amore, Strings, and Continuo in D, BWV 1053 - Reconstruction; Arnold Mehl : 1. (Allegro)' by 'Camerata Bern' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/classical/classical.00000_cover.jpg'
# Fetched album URL from Last.fm:
# Empty URL provided.
# Fetched album URL from Spotify: https://i.scdn.co/image/ab6761610000e5eb65e57a760099d14a0807cd9a
# Cover image downloaded and resized for 'Symphony No. 36 in C Major, K425 'Linz' - IV. Finale (Presto)' by 'Gunther Hasselmann' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/classical/classical.00014_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/731aa96cf1f41a3ccdf61dbe65c818de6cd78e77
# Cover image downloaded and resized for 'J.S. Bach: Cantata "Ich steh mit einem Fuß im Grabe" BWV 156 - Sinfonia' by 'Heinz Holliger' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/classical/classical.00003_cover.jpg'
# Cover image not found for 'Satie: Mercure' by 'Bernard Herrmann, The London Festival Players, London Philharmonic Orchestra' from both Last.fm and Spotify. Retrying after delay.
# Cover image not found for 'Satie: Mercure' by 'Bernard Herrmann, The London Festival Players, London Philharmonic Orchestra' from both Last.fm and Spotify.
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/ab6761610000e5eb669845465a41edd9d504b3bc
# Cover image downloaded and resized for 'Schubert: Fantasy in C Major "Wanderer", D 760 - Solo piano - 1. Allegro con fuoco ma non troppo' by 'Alfred Brendel' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/classical/classical.00067_cover.jpg'
# Fetched URL from Last.fm:
# Empty URL provided.
# Fetched album URL from Last.fm:
# Empty URL provided.
# Fetched album URL from Spotify: https://i.scdn.co/image/41e9c445429209ee9966bef284edebd79cc63515
# Cover image downloaded and resized for 'The Four Seasons, Op. 8: Concerto No. 3 for Violin in F Major, RV 293 "Autumn": I. Allegro' by 'Jose-Luis Garcia' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/classical/classical.00098_cover.jpg'
# Fetched album URL from Last.fm:
# Empty URL provided.
# Fetched album URL from Spotify: https://i.scdn.co/image/ab67616d0000b273d3aa1119d16ab06a0b039526
# Cover image downloaded and resized for 'The Four Seasons, Op. 8: Concerto No. 3 for Violin in F Major RV 293 "Autumn": II. Adagio Molto' by 'José Louis Garcia' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/classical/classical.00099_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/41e9c445429209ee9966bef284edebd79cc63515
# Cover image downloaded and resized for 'The Four Seasons, Op. 8: Spring: Allegro I.' by 'José-Luis Garcia' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/classical/classical.00089_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/ab67616d0000b27398c912ce3958e4a6719bad8f
# Cover image downloaded and resized for 'Beethoven: Symphony No.1 in C, Op.21 - 4. Finale (Adagio - Allegro molto e vivace)' by 'Gewandhausorchester Leipzig' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/classical/classical.00049_cover.jpg'
# Cover image not found for 'Satie: La belle excentrique' by 'Bernard Herrmann, The London Festival Players, London Philharmonic Orchestra' from both Last.fm and Spotify. Retrying after delay.
# Cover image not found for 'Satie: La belle excentrique' by 'Bernard Herrmann, The London Festival Players, London Philharmonic Orchestra' from both Last.fm and Spotify.
# Fetched URL from Last.fm:
# Empty URL provided.
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/ab67616d0000b2739dc62af4db4272fd76f19b32
# Cover image downloaded and resized for 'Madness Is Gladness' by 'Prince Buster' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/reggae/reggae.00095_cover.jpg'
# Fetched album URL from Last.fm:
# Empty URL provided.
# Cover image not found for 'Israelites' by '100 60s' from both Last.fm and Spotify. Retrying after delay.
# Cover image not found for 'Israelites' by '100 60s' from both Last.fm and Spotify.
# Fetched album URL from Last.fm:
# Empty URL provided.
# Cover image not found for 'Israelites' by '100 60s' from both Last.fm and Spotify. Retrying after delay.
# Cover image not found for 'Israelites' by '100 60s' from both Last.fm and Spotify.
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/ab6761610000e5ebb7c04e289a76164682742935
# Cover image downloaded and resized for 'Ghetto Supastar (That is What You Are) (Album Version)' by 'Pras' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/reggae/reggae.00052_cover.jpg'
# Fetched URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/bec0312a455ae1b72c1ff6f2bae9f35a.png
# Cover image downloaded and resized for 'Ketchy Shuby (Instrumental)' by 'Peter Tosh' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/reggae/reggae.00090_cover.jpg'
# Fetched URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/0c9f71bb666e4aa18f850c0289fe7dbc.png
# Cover image downloaded and resized for 'Boney Dog' by 'The Now Generation' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/reggae/reggae.00089_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/be146a84cc7f88594eba0ef842a7dc3ce7836b24
# Cover image downloaded and resized for 'Jah Is My Driver (2002 Digital Remaster)' by 'Burning Spear' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/reggae/reggae.00062_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/ab6761610000e5ebad11b8ecb039058c23b08389
# Cover image downloaded and resized for 'Hip-Hopera ("Mr. Punk") (feat. The Fugees)' by 'Bounty Killer' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/reggae/reggae.00074_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/ab6761610000e5ebad11b8ecb039058c23b08389
# Cover image downloaded and resized for 'Hip-Hopera ("Mr. Punk") (feat. The Fugees)' by 'Bounty Killer' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/reggae/reggae.00073_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/ab6761610000e5eb6afd7b961ed4176236198308
# Cover image downloaded and resized for 'D.I.S.C.O (English Version)' by 'Ottawan' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/disco/disco.00045_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/ab6761610000e5ebb75ca1c0223fc450dfe3c1ec
# Cover image downloaded and resized for 'I Am What I Am (Album Version)' by 'Gloria Gaynor' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/disco/disco.00078_cover.jpg'
# Fetched album URL from Last.fm:
# Empty URL provided.
# Fetched URL from Spotify: https://i.scdn.co/image/ab67616d0000b2737f5400cefb6ba58ee1d9c7c4
# Cover image downloaded and resized for 'Sex' by 'Sabrina Firda Firda Firda Firda' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/disco/disco.00018_cover.jpg'
# Fetched URL from Last.fm:
# Empty URL provided.
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/d9726c3e0ae6d3b5c55116ae1e857eda058ff309
# Cover image downloaded and resized for 'Patches (Re-Recorded/Re-Mastered Version)' by 'Clarence Carter' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/disco/disco.00020_cover.jpg'
# Fetched album URL from Last.fm:
# Empty URL provided.
# Fetched album URL from Spotify: https://i.scdn.co/image/ab6761610000e5eb9722e16a886767adf1178f92
# Cover image downloaded and resized for 'Sing A Song (Album Version)' by 'Earth, Wind & Fire' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/disco/disco.00016_cover.jpg'
# Fetched album URL from Last.fm:
# Empty URL provided.
# Cover image not found for 'Boogie Nights' by 'Heatwave | The Three Degrees' from both Last.fm and Spotify. Retrying after delay.
# Cover image not found for 'Boogie Nights' by 'Heatwave | The Three Degrees' from both Last.fm and Spotify.
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/1d5a05673975ba0c378cd280344e000b0b865620
# Cover image downloaded and resized for 'Stayin' Alive(2009 Remastered Version)' by 'Bee Gees' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/disco/disco.00014_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Error fetching artist image from Spotify for 'Various Artists': list index out of range
# Cover image not found for 'Better Do It Salsa' by 'Various Artists' from both Last.fm and Spotify. Retrying after delay.
# Error fetching artist image from Spotify for 'Various Artists': list index out of range
# Cover image not found for 'Better Do It Salsa' by 'Various Artists' from both Last.fm and Spotify.
# Fetched album URL from Last.fm:
# Empty URL provided.
# Fetched album URL from Spotify: https://i.scdn.co/image/ab67616d0000b273a6b3afcdd15b2b561e684337
# Cover image downloaded and resized for 'Shake Your Groove Thing (Album Version)' by 'Peaches & Herb' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/disco/disco.00066_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/8c81130db7b5f933412c4906c30327817f1e1b43
# Cover image downloaded and resized for 'Bloodline (Album Version)' by 'Slayer' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/metal/metal.00035_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Error fetching artist image from Spotify for 'Lemmy Kilmister': list index out of range
# Cover image not found for 'Enter Sandman' by 'Lemmy Kilmister' from both Last.fm and Spotify. Retrying after delay.
# Error fetching artist image from Spotify for 'Lemmy Kilmister': list index out of range
# Cover image not found for 'Enter Sandman' by 'Lemmy Kilmister' from both Last.fm and Spotify.
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/ab6761610000e5ebda4bd2b213cae330e2a4a901
# Cover image downloaded and resized for 'Wake Up (Album Version)' by 'Rage Against the Machine' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/metal/metal.00097_cover.jpg'
# Fetched URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/a5ec1c81c8e8eed0d85f1a4bc2bcda87.png
# Cover image downloaded and resized for 'Phantom of the Opera (Live at the Hammersmith Odeon) [1998 Remaster]' by 'Iron Maiden' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/metal/metal.00093_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/ab6761610000e5eb5328c468cef8019bc41b63a8
# Cover image downloaded and resized for 'TKD Dance (Live)' by 'V.A' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/metal/metal.00060_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/ab6761610000e5ebda4bd2b213cae330e2a4a901
# Cover image downloaded and resized for 'Freedom (Album Version)' by 'Rage Against the Machine' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/metal/metal.00099_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/b040846ceba13c3e9c125d68389491094e7f2982
# Cover image downloaded and resized for 'Tear It Up (Live At Wembley Stadium / July 1986)' by 'Queen' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/metal/metal.00059_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched URL from Spotify: https://i.scdn.co/image/ab67616d0000b273ec1b0ed7d97278d6752eb8f4
# Cover image downloaded and resized for 'Mindtraveller' by 'Earl Falconer' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/metal/metal.00000_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/ab6772690000c46c1110b1a024312710e7c796c4
# Cover image downloaded and resized for 'Beyond the Black Hole - Original Version' by 'Gamma Ray' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/metal/metal.00001_cover.jpg'
# Fetched URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/d3018b7e2b1373fa8f5443dafa92f04a.png
# Cover image downloaded and resized for 'Nightfall by the Shore of Time' by 'Dark Tranquillity' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/metal/metal.00015_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/ab6761610000e5eb1d592c2d28375da088c00ff7
# Cover image downloaded and resized for 'Glamour Boys (Album Version)' by 'Living Colour' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/metal/metal.00029_cover.jpg'
# Fetched URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/d3018b7e2b1373fa8f5443dafa92f04a.png
# Cover image downloaded and resized for 'My Faeryland Forgotten' by 'Dark Tranquillity' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/metal/metal.00010_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/ab6761610000e5eb3a49b0a3954e460a8a76ed90
# Cover image downloaded and resized for 'Joy Of Pepsi' by 'Britney Spears' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/pop/pop.00033_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/ab6761610000e5eb3a49b0a3954e460a8a76ed90
# Cover image downloaded and resized for 'The Red Wonder 10 Year Anniversary Megamix' by 'Britney Spears' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/pop/pop.00021_cover.jpg'
# Fetched URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/934043f904d1e57e5d7d12a205d15609.png
# Cover image downloaded and resized for 'Crush (Album Version)' by 'Mandy Moore' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/pop/pop.00087_cover.jpg'
# Fetched URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/934043f904d1e57e5d7d12a205d15609.png
# Cover image downloaded and resized for 'In My Pocket (Album Version)' by 'Mandy Moore' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/pop/pop.00092_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Cover image not found for 'Lady Marmalade' by 'Billboard Hot 100' from both Last.fm and Spotify. Retrying after delay.
# Cover image not found for 'Lady Marmalade' by 'Billboard Hot 100' from both Last.fm and Spotify.
# Fetched URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/934043f904d1e57e5d7d12a205d15609.png
# Cover image downloaded and resized for 'Crush (Album Version)' by 'Mandy Moore' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/pop/pop.00090_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/ab6761610000e5eb65c99d6d784dc2cabd2a5492
# Cover image downloaded and resized for 'Everything My Heart Desires (Album Version)' by 'Mandy Moore' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/pop/pop.00091_cover.jpg'
# Fetched URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/1023fccdac0a623c08acdb886217c7ee.png
# Cover image downloaded and resized for 'Love You For Always (Album Version)' by 'Mandy Moore' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/pop/pop.00095_cover.jpg'
# Cover image not found for 'Leaning on the Everlasting Arm (2006 Remaster)' by 'Ladysmith Black Mambazo with the Winans' from both Last.fm and Spotify. Retrying after delay.
# Cover image not found for 'Leaning on the Everlasting Arm (2006 Remaster)' by 'Ladysmith Black Mambazo with the Winans' from both Last.fm and Spotify.
# Fetched URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/1023fccdac0a623c08acdb886217c7ee.png
# Cover image downloaded and resized for 'Quit Breaking My Heart (Album Version)' by 'Mandy Moore' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/pop/pop.00096_cover.jpg'
# Fetched URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/679db30507a44a1f80f11fa61a395944.png
# Cover image downloaded and resized for 'Bootylicious feat. Missy Elliot (Remix) (Rockwilder Remix)' by 'Destiny's Child' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/pop/pop.00054_cover.jpg'
# Fetched URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/14433192740cf81e9bb615a6d250d308.png
# Cover image downloaded and resized for 'All for You (DJ Quik Remix)' by 'Janet Jackson' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/pop/pop.00071_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/ab6761610000e5eb3a49b0a3954e460a8a76ed90
# Cover image downloaded and resized for 'Sometimes (Soul Solution Mid Tempo Mix)' by 'Britney Spears' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/pop/pop.00064_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/ab6761610000e5eb21b66418f7f3b86967f85bce
# Cover image downloaded and resized for 'Emotions (Album Version)' by 'Mariah Carey' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/pop/pop.00098_cover.jpg'
# Fetched URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/14433192740cf81e9bb615a6d250d308.png
# Cover image downloaded and resized for 'All for You (DJ Quik Remix)' by 'Janet Jackson' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/pop/pop.00067_cover.jpg'
# Fetched album URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# Fetched album URL from Spotify: https://i.scdn.co/image/ab6761610000e5ebdb59e1c017a93648b119f0cc
# Cover image downloaded and resized for 'Ain't No Mountain High Enough (Live At VH1 Divas 2000) (feat. Mariah Carey)' by 'Diana Ross' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/pop/pop.00063_cover.jpg'
# Fetched URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/1023fccdac0a623c08acdb886217c7ee.png
# Cover image downloaded and resized for 'Candy (Album Version)' by 'Mandy Moore' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/pop/pop.00089_cover.jpg'
# Fetched URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/679db30507a44a1f80f11fa61a395944.png
# Cover image downloaded and resized for 'Bootylicious feat. Missy Elliot (Remix) (Rockwilder Remix)' by 'Destiny's Child' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/pop/pop.00060_cover.jpg'
# Fetched URL from Last.fm: https://lastfm.freetls.fastly.net/i/u/300x300/934043f904d1e57e5d7d12a205d15609.png
# Cover image downloaded and resized for 'Saturate Me (Album Version)' by 'Mandy Moore' as '/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images/pop/pop.00000_cover.jpg'
# Processing of error files completed.

# %%
import os
import requests
from PIL import Image
from io import BytesIO

def download_image(image_url):
    """
    Download an image from a URL and return it as a PIL Image object.

    Parameters:
    - image_url (str): The URL of the image to download.

    Returns:
    - Image: The downloaded image as a PIL Image object.
    """
    response = requests.get(image_url)
    img = Image.open(BytesIO(response.content))
    return img

def convert_to_jpg_and_resize(image, save_path, size=(200, 200)):
    """
    Convert an image to JPG format, resize it, and save it.

    Parameters:
    - image (Image): The image to convert and resize.
    - save_path (str): The path to save the converted JPG file.
    - size (tuple): The desired size for the output image, default is (200, 200).
    """
    # Convert the image to RGB mode if it's not already
    if image.mode != 'RGB':
        image = image.convert('RGB')
    # Resize the image
    image = image.resize(size)
    # Save the image in JPG format
    image.save(save_path, 'JPEG')

if __name__ == "__main__":
    # Example usage
    image_url = "https://geo-media.beatport.com/image_size/500x500/2e97877a-1133-480c-b478-fcafcedb7551.jpg"

    save_path = "/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images_missing/rock.00023_cover.jpg"
    
    # Ensure the save directory exists
    os.makedirs(os.path.dirname(save_path), exist_ok=True)
    
    # Download and save the image
    img = download_image(image_url)
    convert_to_jpg_and_resize(img, save_path)
    print(f"Image saved as {save_path}")
# Out:
# Image saved as /Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/images_missing/rock.00023_cover.jpg

# %%
title_artist = pd.read_csv("/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/title_artist.csv")

# Rename the column 'label' to 'genre'
title_artist.rename(columns={'label': 'genre'}, inplace=True)

# Count the number of distinct values per genre
genre_counts = title_artist['genre'].value_counts()

# Display the result
print(genre_counts)
# Out:
# genre
# rock         100
# blues         98
# classical     97
# jazz          97
# pop           95
# reggae        95
# metal         94
# hiphop        93
# disco         89
# country       79
# Name: count, dtype: int64

# %%
import pandas as pd

# Load the CSV files
metadata_df = pd.read_csv('/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/metadata_.csv')
title_artist_df = pd.read_csv('/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/title_artist.csv')

# Rename columns for consistency
metadata_df.rename(columns={'label': 'genre', 'file_path': 'filepath'}, inplace=True)
title_artist_df.rename(columns={'label': 'genre'}, inplace=True)

# Merge the DataFrames on the 'filename' column
merged_df = pd.merge(metadata_df, title_artist_df[['filename', 'title', 'artist']], on='filename', how='left')

# Reorder the columns
expected_columns = ['filename', 'genre', 'title', 'artist', 'tempo', 'keys', 'loudness', 'filepath']
available_columns = [col for col in expected_columns if col in merged_df.columns]
merged_df = merged_df[available_columns]

# Save the merged DataFrame to a new CSV file
merged_df.to_csv('/Users/datoapanta/Desktop/mma_2024/dataset/data/gtzan/metadata.csv', index=False)

# Display the first few rows of the resulting DataFrame
print(merged_df.head())
# Out:
#           filename  genre                              title           artist  \
# 0  blues.00000.wav  blues  One Bourbon, One Scotch, One Beer  John Lee Hooker
# 1  blues.00001.wav  blues                    I'm In The Mood  John Lee Hooker
# 2  blues.00002.wav  blues          Think Twice Before You Go  John Lee Hooker
# 3  blues.00003.wav  blues           I'm Bad Like Jesse James  John Lee Hooker
# 4  blues.00004.wav  blues                 Walkin' The Boogie  John Lee Hooker
#
#         tempo                                               keys  loudness  \
# 0  123.046875  {'G major': 11.35, 'G minor': 9.18, 'C major':...    -44.27
# 1   67.999589  {'G major': 9.67, 'G minor': 9.22, 'C major': ...    -50.30
# 2  161.499023  {'E minor': 10.58, 'E major': 9.3, 'A minor': ...    -40.07
# 3   63.024009  {'E minor': 9.77, 'E major': 8.45, 'B major': ...    -53.16
# 4  135.999178  {'A# major': 10.19, 'A# minor': 10.09, 'D mino...    -46.26
#
#                                             filepath
# 0  /Users/datoapanta/Desktop/mma_2024/dataset/dat...
# 1  /Users/datoapanta/Desktop/mma_2024/dataset/dat...
# 2  /Users/datoapanta/Desktop/mma_2024/dataset/dat...
# 3  /Users/datoapanta/Desktop/mma_2024/dataset/dat...
# 4  /Users/datoapanta/Desktop/mma_2024/dataset/dat...
